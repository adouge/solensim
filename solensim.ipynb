# %%
run src/solensim
# Out:
# solensim v0.1.3 WIP Solenoid design tool
# ...
# iPython interface handle initialized as "e".
#
# Default settings:
# E: Electron energy [MeV]: 3.5
# R: RMS Beam radius [mm]: 1
# g: Geomtery [mm]: None
# s: Ampere-turns [A*N]: None
#
# Default targets:
# Target peak B [mT]: [75, 125]
# Target FWHM [mm]: [45, 55]
# Target f [cm]: [50, 50]
# Target g [mm]: None
# Target s [N*A]: None
#
# Placeholder help text:
#
#             To view settings:
#                 handle.settings()
#             To view set targets:
#                 handle.targets()
#             To set targets, initial parameter x:
#                 handle.target_x = new value / interval
#                 handle.x = new value
#             Permanent settings:
#                 E [MeV] - electron energy (currently only monochrome beams handled)
#                 R_mm [mm] - "beam radius"
#               call handle.process_E_R() to apply changes - currently a non-developed feature;
# ...

# %%
demos.calc_REGAE(e)
# Out:
# Parameters:
#  - s: 9000.000
#  - R_mean: 79.750 mm, a: 41.800 mm, b: 99.500 mm
# Resulting characteristics:
#  - Peak axial field: 78.279 mT
#  - Effective field length: 102.000 mm
#  - Focal distance for given E: 27.679 cm
#  - Spherical aberration for given E: 1.407E-10 m
#  - Focal spot radius: 6.636E-03 fm

# %%
demos.opt_REGAE(e)
# Out:
# /usr/lib/python3.8/site-packages/scipy/optimize/_trustregion_constr/projections.py:182: UserWarning: Singular Jacobian matrix. Using SVD decomposition to perform the factorizations.
#   warn('Singular Jacobian matrix. Using SVD decomposition to ' +
# /usr/lib/python3.8/site-packages/scipy/optimize/_hessian_update_strategy.py:183: UserWarning: delta_grad == 0.0. Check if the approximated function is linear. If the function is linear better results can be obtained by defining the Hessian as zero instead of using quasi-Newton approximations.
#   warn('delta_grad == 0.0. Check if the approximated '
# `gtol` termination condition is satisfied.
# Number of iterations: 116, function evaluations: 170, CG iterations: 0, optimality: 3.80e-09, constraint violation: 0.00e+00, execution time:  4.8 s.
# Settings:
#  - g [mm]: [79.75, 41.8, 99.5]
#  - s [A*N]: 9000
# Targets:
#  - peak B [mT]: 80
#  - FWHM [mm]: 102
#  - f [cm]: 27.7
# ...

# %%
demos.opt_best(e)
# Out:
# /usr/lib/python3.8/site-packages/scipy/optimize/_trustregion_constr/projections.py:182: UserWarning: Singular Jacobian matrix. Using SVD decomposition to perform the factorizations.
#   warn('Singular Jacobian matrix. Using SVD decomposition to ' +
# /usr/lib/python3.8/site-packages/scipy/optimize/_hessian_update_strategy.py:183: UserWarning: delta_grad == 0.0. Check if the approximated function is linear. If the function is linear better results can be obtained by defining the Hessian as zero instead of using quasi-Newton approximations.
#   warn('delta_grad == 0.0. Check if the approximated '
# `gtol` termination condition is satisfied.
# Number of iterations: 22, function evaluations: 65, CG iterations: 0, optimality: 2.26e-09, constraint violation: 3.34e-13, execution time:  2.1 s.
# Settings:
#  - g [mm]: [30, 40, 50]
#  - s [A*N]: 4000
# Targets:
#  - peak B [mT]: [100, 100]
#  - FWHM [mm]: [25, 75]
#  - f [cm]: [50, 50]
# ...
